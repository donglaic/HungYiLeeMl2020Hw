# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from DataReader import DataReader

# %%
# read data
dr = DataReader(val_size=0.1)
dr.read()
X_train, X_val, X_test, y_train, y_val = dr.data()

X_test = np.concatenate((np.ones((X_test.shape[0],1),dtype=np.int64),X_test),axis=1)
# X_val = np.concatenate((np.ones((X_val.shape[0],1),dtype=np.int64),X_val),axis=1)

# %%
lr.fit(X_train,y_train,X_val,y_val)

history = lr.get_history()

plt.plot(range(epoches),history['train accuray'],range(epoches),history['validation accuray'])
plt.legend(['train','test'])
plt.title('accuracy')

plt.figure()
plt.plot(range(epoches),history['train loss'],range(epoches),history['validation loss'])
plt.legend(['train','test'])
plt.title('loss')

lr.best_accuracy
# Out:
# better accuracy found:0.8636196092886104, model saved!
# better accuracy found:0.8638039071138961, model saved!
# better accuracy found:0.866015481017324, model saved!
# better accuracy found:0.8663840766678953, model saved!
# better accuracy found:0.8669369701437524, model saved!
# better accuracy found:0.8689642462218946, model saved!
# better accuracy found:0.8706229266494655, model saved!
# better accuracy found:0.8743088831551787, model saved!
# epoch:10 train accuray:0.8777800532459553 validation accuray:0.8684113527460375
# epoch:20 train accuray:0.8796231824697932 validation accuray:0.8700700331736085
# epoch:30 train accuray:0.8804013925865247 validation accuray:0.8704386288241799
# epoch:40 train accuray:0.8818349375383985 validation accuray:0.8691485440471802
# epoch:50 train accuray:0.8821216465287733 validation accuray:0.8684113527460375
# epoch:60 train accuray:0.8811386442760598 validation accuray:0.8730187983781792
# epoch:70 train accuray:0.8817734998976039 validation accuray:0.8715444157758938
# epoch:80 train accuray:0.8812410403440508 validation accuray:0.8695171396977516
# epoch:90 train accuray:0.881261519557649 validation accuray:0.8708072244747512
# epoch:100 train accuray:0.8803604341593283 validation accuray:0.8673055657943236
# 0.8743088831551787

# %%
lr.theta = np.load('theta.npy')

p = lr.predict(X_test)

import pandas as pd
df = pd.DataFrame({'id':list(range(X_test.shape[0])),
                   'label':p.flatten()})

df.to_csv('result.csv',index=None)
